# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = Symbol('x')

# %%
x
# Out:
# x

# %% [markdown]
# # Задание 1.

# %% [markdown]
# ## 1.

# %% [markdown]
# ### Получите значение MSE меньшее 0.75.

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([3, 1, -0.5, 1.2, 2.5, 0.8, -2, -3.5, -3, -5])
    plt.xlim(-10, 10)
    plt.ylim(-5, 5)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
def calcul_mse(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))

    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([3, 1, -0.5, 1.2, 2.5, 0.8, -2, -3.5, -3, -5])
    
    x_range = np.linspace(-10, 10, num=100)
    function_Y = [function(x_) for x_ in x_range]
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    return MSE

# %%
f1 = 2 * x * sin(2 * x + 5) + 5 * sin(2 * x + 5) + 2
f1
# Out:
# 2*x*sin(2*x + 5) + 5*sin(2*x + 5) + 2

# %%
print_points_ands_function1(f1)
# Out:
# MSE = 90.56454338961888

# %%
y = Symbol('y')

# %%
mse = 1/10*((3 - y) ** 2 + (1 - y) ** 2 + (-0.5 - y) ** 2 +(1.2 - y) ** 2 + (2.5 - y) ** 2 + (0.8 - y) ** 2 + (-2 - y) ** 2 + (-3.5 - y) ** 2 + (-3 - y) ** 2 + (-5 - y) ** 2 )
mse
# Out:
#              2              2                                  2                    2              2               2               2               2                 2                                   2
# 0.1*(0.8 - y)  + 0.1*(1 - y)  + 0.144*(1 - 0.833333333333333*y)  + 0.625*(1 - 0.4*y)  + 0.1*(3 - y)  + 0.1*(-y - 5)  + 0.1*(-y - 3)  + 0.1*(-y - 2)  + 0.1*(-y - 0.5)  + 1.225*(-0.285714285714286*y - 1)

# %%
diff(mse)
# Out:
# 2.0*y + 1.1

# %%
solve_univariate_inequality(diff(mse)<0,y)
# Out:
# And(-oo < y, y < -0.55)

# %%
f1_2 = 2 * x * sin(2 * x + 5) + 5 * sin(2 * x + 5)- 0.55
print_points_ands_function1(f1_2)
# Out:
# MSE = 75.68559583662868

# %%
print_points_ands_function1(f1_2 + -0.7)
# Out:
# MSE = 73.87617886129803

# %%
min_mse = 1000
min_iter = 0
for mult in np.arange(-5, 5, 0.1):
    f1_3 = expand(f1_2.subs(x, x * mult))
    calcul = calcul_mse(f1_3)
    if min_mse > calcul:
        min_mse = calcul
        min_iter = mult
else:
    print(f'x при минимальном MSE: {min_iter}')
    print(f'минимальный MSE: {min_mse}')
# Out:
# x при минимальном MSE: -1.0000000000000142
# минимальный MSE: 6.220286854077441

# %%
f1_3 = f1_2.subs(x, x * min_iter)
print_points_ands_function1(f1_3)
# Out:
# MSE = 6.220286854077441
