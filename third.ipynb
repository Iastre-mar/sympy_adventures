# %%
from sympy import *
from sympy.plotting import plot
from matplotlib import pyplot as plt
# %matplotlib widget
# %matplotlib inline

# %%
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
x = Symbol('x')

# %%
f = x + 1 
f
# Out:
# x + 1

# %%
f.subs(x, 0)
# Out:
# 1

# %%
plot(f)

# %%
f = -3*x +5

# %%
plot(f)

# %%
f.subs(x, 2)
# Out:
# -1

# %%
f = 3 * x**2 +3*x -6

# %%
plot(f)

# %%
f.subs(x,1)
# Out:
# 0

# %%
f = 2* x**4+x*3-6*x**2+7*x+1

# %%
plot(f)

# %%
f = (x**2)**x

# %%
plot(f)

# %%
interactive_plot = interactive(f, k=(-5,5,0.1), b=(-5,5,0.1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-e6f611de864f> in <module>
# ----> 1 interactive_plot = interactive(f, k=(-5,5,0.1), b=(-5,5,0.1))
#
# TypeError: 'module' object is not callable

# %%
type(interactive)
# Out:
# module

# %%
dir(interactive)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'init_printing',
#  'init_session',
#  'printing',
#  'session']

# %%
f = 4 *x +5
plot(f)

# %%
f =4*x**2+4*x+10
plot(f)

# %%
f = 100*log(x)
plot(f)

# %%
f = 200 * sqrt(x)
plot(f, (x,0,100))

# %%
f = 100 * exp(0.2*x)
plot(f)

# %%
f = 5 * x + 1.5
solve(f)
# Out:
# [-0.3]

# %%
plot(f)

# %%
solve_univariate_inequality(f>0,x)
# Out:
# And(-0.3 < x, x < oo)

# %%
f = 2 * exp(0.2*x) - 1
solve(f)
# Out:
# [-3.46573590279973]

# %%
plot(f)

# %%
solve_univariate_inequality(f>0,x)
# Out:
# And(x < oo, -5.0*log(2) < x)

# %%
f = 3 * sqrt(x) - 15
solve(f)
# Out:
# [25]

# %%
plot(f, (x, 0, 100))

# %%
f = 2*log(x) + 5
solve(f)
# Out:
#   -5/2
# [e    ]

# %%
plot(f)

# %%
f = -5*x**2-10*x+100
solve(f)
# Out:
#         ____      ____
# [-1 + \/ 21 , - \/ 21  - 1]

# %%
plot(f)

# %%
10 / -10
# Out:
# -1.0

# %%
f.subs(x,-1)
# Out:
# 105
